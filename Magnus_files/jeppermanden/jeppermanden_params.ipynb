# %%
import time 
start_time = time.time()

# %%
#!/usr/bin/env python3

from classy_NEDE import Class

# Instantiate CLASS
cosmo = Class()

# Set ONLY your parameter set
cosmo.set({
    'output': 'tCl,pCl,lCl,mPk',
    'omega_b': 0.022,
    'omega_cdm': 0.12,
    'h': 0.67,
    'A_s': 2.1e-9,
    'n_s': 0.96,
    'tau_reio': 0.06,

    'N_ncdm_interacting': 1,
    'm_ncdm_interacting': 0.1,
    'deg_ncdm_interacting': 1,
    'log10G_eff_ncdm_interacting': -2,

    'N_ncdm_standard': 2.0,
    'm_ncdm_standard': 0.0,
    'deg_ncdm_standard': 1,

    'N_ur': 0.0,

    'r': 0.1,
    'modes': 's,t',
    'k_pivot': 0.05,

    'ncdm_fluid_approximation': 3,

    'P_k_max_h/Mpc': 1.0,
    'lensing': 'yes'
})

# Run computation
cosmo.compute()

# Optional sanity print
try:
    derived = cosmo.get_current_derived_parameters(
        ["h", "Omega_m", "Omega_r", "sigma8", "Neff"]
    )
    print("Derived parameters:", derived)
except:
    print("Computation finished successfully.")

# Clean up (good practice)
cosmo.struct_cleanup()
cosmo.empty()

print("Done.")
# Out:
# DEBUG split(prepass): legacy_flag=0 legacy_N=0  flag_std=1 flag_int=1  Nstd_in=2 Nint_in=1  => Nstd=2 Nint=1 Ntot=3 (local N_ncdm=3)
# DEBUG split(Geff_final): Nstd=2 Nint=1 Ntot=3  Geff_species=0.000e+00,0.000e+00,1.000e-02
# Computation finished successfully.
# Done.

# %%
#!/usr/bin/env python3

from classy_NEDE import Class

# Instantiate CLASS
cosmo = Class()

# Set ONLY your parameter set
cosmo.set({
    'output': 'tCl,pCl,lCl,mPk',
    'omega_b': 0.022,
    'omega_cdm': 0.12,
    'h': 0.67,
    'A_s': 2.1e-9,
    'n_s': 0.96,
    'tau_reio': 0.06,

    'N_ncdm_interacting': 1,
    'm_ncdm_interacting': 0.1,
    'deg_ncdm_interacting': 1,
    'log10G_eff_ncdm_interacting': -2,

    'N_ncdm_standard': 2.0,
    'm_ncdm_standard': 0.0,
    'deg_ncdm_standard': 1,

    'N_ur': 0.0,

    'r': 0.1,
    'modes': 's,t',
    'k_pivot': 0.05,

    'ncdm_fluid_approximation': 3,

    'P_k_max_h/Mpc': 1.0,
    'lensing': 'yes'
})

# Run computation
cosmo.compute()

# Optional sanity print
try:
    derived = cosmo.get_current_derived_parameters(
        ["h", "Omega_m", "Omega_r", "sigma8", "Neff"]
    )
    print("Derived parameters:", derived)
except:
    print("Computation finished successfully.")

# Clean up (good practice)
cosmo.struct_cleanup()
cosmo.empty()

print("Done.")
# Out:
# DEBUG split(prepass): legacy_flag=0 legacy_N=0  flag_std=1 flag_int=1  Nstd_in=2 Nint_in=1  => Nstd=2 Nint=1 Ntot=3 (local N_ncdm=3)
# DEBUG split(Geff_final): Nstd=2 Nint=1 Ntot=3  Geff_species=0.000e+00,0.000e+00,1.000e-02
# Computation finished successfully.
# Done.

# %%
#!/usr/bin/env python3

from classy_NEDE import Class

cosmo = Class()

cosmo.set({
    'output': 'tCl,lCl,pCl,mPk',
    'lensing': 'yes',
    'k_pivot': 0.05,

    'N_ncdm_interacting': 1.0,
    'ncdm_fluid_approximation': 3.0,
    'modes': 's,t',

    'N_ur': 0,
    'N_ncdm_standard': 1.0,
    'deg_ncdm_standard': 2.046,
    'm_ncdm_standard': 0.0,

    'deg_ncdm_interacting': 1.0,

    'omega_b': 0.022834870893010225,
    'omega_cdm': 0.12042954941093752,
    'h': 0.5631113073562523,
    'ln10^{10}A_s': 3.097168991267475,
    'n_s': 0.9603856788971851,
    'tau_reio': 0.04094383751116977,

    'r': 0.152940476712933,
    'm_ncdm_interacting': 0.6259174010641673,
    'log10G_eff_ncdm_interacting': -3.190566778038364,

    'P_k_max_1/Mpc': 8.4445,
    'z_max_pk': 13.65
})

cosmo.compute()

try:
    derived = cosmo.get_current_derived_parameters(
        ["h", "Omega_m", "Omega_r", "sigma8", "Neff"]
    )
    print("Derived parameters:", derived)
except Exception:
    print("Computation finished successfully.")

cosmo.struct_cleanup()
cosmo.empty()

print("Done.")
# Out:
# DEBUG split(prepass): legacy_flag=0 legacy_N=0  flag_std=1 flag_int=1  Nstd_in=1 Nint_in=1  => Nstd=1 Nint=1 Ntot=2 (local N_ncdm=2)
# DEBUG split(Geff_final): Nstd=1 Nint=1 Ntot=2  Geff_species=Computation finished successfully.
# Done.
# 0.000e+00,6.448e-04

# %%
#!/usr/bin/env python3

from classy_NEDE import Class

cosmo = Class()

cosmo.set({
    'output': 'tCl,lCl,pCl,mPk',
    'lensing': 'yes',
    'k_pivot': 0.05,

    'N_ncdm_interacting': 1.0,
    'ncdm_fluid_approximation': 3.0,
    'modes': 's,t',

    'N_ur': 0,
    'N_ncdm_standard': 1.0,
    'deg_ncdm_standard': 2.046,
    'm_ncdm_standard': 0.0,

    'deg_ncdm_interacting': 1.0,

    'omega_b': 0.021983488808989177,
    'omega_cdm': 0.1182101238055424,
    'h': 0.6037093197708772,
    'ln10^{10}A_s': 3.1168053496457784,
    'n_s': 0.9670850035670971,
    'tau_reio': 0.07101328301703548,

    'r': 0.24684260095924515,
    'm_ncdm_interacting': 0.08623580529506125,
    'log10G_eff_ncdm_interacting': -2.462514320398657,

    'P_k_max_1/Mpc': 8.4445,
    'z_max_pk': 13.65
})

cosmo.compute()

try:
    derived = cosmo.get_current_derived_parameters(
        ["h", "Omega_m", "Omega_r", "sigma8", "Neff"]
    )
    print("Derived parameters:", derived)
except Exception:
    print("Computation finished successfully.")

cosmo.struct_cleanup()
cosmo.empty()

print("Done.")
# Out:
# DEBUG split(prepass): legacy_flag=0 legacy_N=0  flag_std=1 flag_int=1  Nstd_in=1 Nint_in=1  => Nstd=1 Nint=1 Ntot=2 (local N_ncdm=2)
# DEBUG split(Geff_final): Nstd=1 Nint=1 Ntot=2  Geff_species=0.000e+00,3.447e-03
# Computation finished successfully.
# Done.

# %%
#!/usr/bin/env python3

from classy_NEDE import Class

cosmo = Class()

cosmo.set({
    'output': 'tCl,lCl,pCl,mPk',
    'lensing': 'yes',
    'k_pivot': 0.05,

    'N_ncdm_interacting': 1.0,
    'ncdm_fluid_approximation': 3.0,
    'modes': 's,t',

    'N_ur': 0,
    'N_ncdm_standard': 1.0,
    'deg_ncdm_standard': 2.046,
    'm_ncdm_standard': 0.0,

    'deg_ncdm_interacting': 1.0,

    'omega_b': 0.021872390210937922,
    'omega_cdm': 0.12118177604520516,
    'h': 0.8401667268303014,
    'ln10^{10}A_s': 3.1783910220550604,
    'n_s': 0.9739219822155585,
    'tau_reio': 0.09004488843032873,

    'r': 0.25096950227005044,
    'm_ncdm_interacting': 0.7503722152641435,
    'log10G_eff_ncdm_interacting': -3.67034129249937,

    'P_k_max_1/Mpc': 8.4445,
    'z_max_pk': 13.65
})

cosmo.compute()

try:
    derived = cosmo.get_current_derived_parameters(
        ["h", "Omega_m", "Omega_r", "sigma8", "Neff"]
    )
    print("Derived parameters:", derived)
except Exception:
    print("Computation finished successfully.")

cosmo.struct_cleanup()
cosmo.empty()

print("Done.")
# Out:
# Computation finished successfully.DEBUG split(prepass): legacy_flag=0 legacy_N=0  flag_std=1 flag_int=1  Nstd_in=1 Nint_in=1  => Nstd=1 Nint=1 Ntot=2 (local N_ncdm=2)
#
# Done.
# DEBUG split(Geff_final): Nstd=1 Nint=1 Ntot=2  Geff_species=0.000e+00,2.136e-04

# %%
print("All done.")
end_time = time.time()
print(f"Total execution time: {end_time - start_time:.2f} seconds")
# Out:
# All done.
# Total execution time: 91.39 seconds
